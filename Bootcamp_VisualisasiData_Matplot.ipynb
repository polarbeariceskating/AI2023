# %% [markdown]
# <a href="https://colab.research.google.com/github/polarbeariceskating/AI2023/blob/main/Bootcamp_VisualisasiData_Matplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 5, 11)
y = x ** 2
plt.plot(x, y, 'r') # 'r' is the color red
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('String Title Here')
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x, y, 'r--')
plt.subplot(1,2,2)
plt.plot(y, x, 'g*-');

# %%
fig, axes = plt.subplots(figsize=(12,3))

axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data)
# Out:
# (array([11., 10.,  8., 14.,  9.,  9.,  7., 13., 10.,  9.]),
#  array([  3. , 101.5, 200. , 298.5, 397. , 495.5, 594. , 692.5, 791. ,
#         889.5, 988. ]),
#  <BarContainer object of 10 artists>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True);

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y1 = [10, 12, 5, 8, 7]
y2 = [8, 9, 11, 6, 12]

plt.plot(x, y1, label='Seri 1')
plt.plot(x, y2, label='Seri 2')

plt.legend()
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 12, 5, 8, 7]

plt.plot(x, y)
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')

plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 12, 5, 8, 7]

plt.plot(x, y)
plt.title('Grafik Contoh')

plt.show()
