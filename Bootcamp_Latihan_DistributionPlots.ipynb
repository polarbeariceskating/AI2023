# %% [markdown]
# <a href="https://colab.research.google.com/github/polarbeariceskating/KonsepData-AI/blob/main/Bootcamp_Latihan_DistributionPlots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(tips['total_bill'],kde=False,bins=30)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# jointplot
sns.jointplot(x='total_bill',y='tip',data=tips,kind='scatter')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %%
# pairplot
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')

# %%
# rugplot
sns.rugplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
# kdeplot
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# membuat dataset
dataset = np.random.randn(25)

# membuat rugplot
sns.rugplot(dataset);

# membuat x-axis untuk plot
x_min = dataset.min() - 2
x_max = dataset.max() + 2

# nilai 100 untuk equally spaced points dari x_min ke x_max
x_axis = np.linspace(x_min,x_max,100)

# Set up bandwidth,
url = 'http://en.wikipedia.org/wiki/Kernel_density_estimation#Practical_estimation_of_the_bandwidth'

bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2


# membuat kernel kosong
kernel_list = []

for data_point in dataset:

    # membuat kernel
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)

    #Scale untuk plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis,kernel,color = 'grey',alpha=0.5)

plt.ylim(0,1)
# Out:
# (0.0, 1.0)
